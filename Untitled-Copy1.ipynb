# %%
import requests
from bs4 import BeautifulSoup as bs
import requests
import json

# %%
HEADER = {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'}
# website = 'https://edusanjal.com/college/texas-international-higher-secondary-school-and-college/'
website = 'https://edusanjal.com/college'

# %%
result = requests.get(website,headers=HEADER)
content = result.text
edusanjal = bs(content,"lxml")
# print(soup.prettify())
print(soup.head.title)
# Out:
# <title>Colleges in Nepal - Edusanjal</title>

# %% [markdown]
# #### find all the urls of card divs in a page

# %%
urls=[]
main_div = edusanjal.find('div', class_='grid gap-8 md:grid-cols-2 lg:grid-cols-3 lg:max-w-full')
div_list = main_div.find_all('div', class_='overflow-hidden bg-white rounded shadow-xl')
for div in div_list:
    link = div.find('a')['href']
    link = link[8:]
    total_url= website+link
    urls.append(total_url)
print(urls)
# Out:
# ['https://edusanjal.com/college/texas-international-higher-secondary-school-and-college/', 'https://edusanjal.com/college/padmashree-international-college/', 'https://edusanjal.com/college/kings-college/', 'https://edusanjal.com/college/ist-college/', 'https://edusanjal.com/college/janamaitri-multiple-campus/', 'https://edusanjal.com/college/cca-school-accountancy/', 'https://edusanjal.com/college/nepal-college-information-technology/', 'https://edusanjal.com/college/khwopa-college/', 'https://edusanjal.com/college/british-college/', 'https://edusanjal.com/college/kist-college/', 'https://edusanjal.com/college/prime-college/', 'https://edusanjal.com/college/softwarica-college-it-and-e-commerce/', 'https://edusanjal.com/college/center-for-leadership-and-entrepreneurship/', 'https://edusanjal.com/college/kantipur-college-management-and-information-technology/', 'https://edusanjal.com/college/silver-mountain-school-hotel-management/', 'https://edusanjal.com/college/nepal-mega-college/', 'https://edusanjal.com/college/premier-college/', 'https://edusanjal.com/college/lalitpur-engineering-college/', 'https://edusanjal.com/college/public-youth-campus/', 'https://edusanjal.com/college/peoples-campus/']

# %%
for url in urls:
    response = requests.get(url,headers=HEADER)
    html_content = response.text
    soup = bs(html_content,"lxml")
    print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Texas International College - Edusanjal
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <script>
#    partytown = { debug: false, forward: [], lib: "/~partytown/" }
#   </script>
#   <script>
#    /* Partytown 0.7.6 - MIT builder.io */
# !function(t,e,n,i,r,o,a,d,s,c,p,l){function u(){l||(l=1,"/"==(a=(o.lib||"/~partytown/")+(o.debug?"debug/":""))[0]&&(s=e.querySelectorAll('script[type="text/partytown"]'),i!=t?i.dispatchEvent(new CustomEvent("pt1",{detail:t})):(d=setTimeout(f,1e4),e.addEventListener("pt0",w),r?h(1):n.serviceWorker?n.serviceWorker.register(a+(o.swPath||"partytown-sw.js"),{scope:a}).then((function(t){t.active?h():t.installing&&t.installing.addEventListener("statechange",(function(t){"activated"==t.target.state&&h()}))}),console.error):f())))}function h(t){c=e.createElement(t?"script":"iframe"),t||(c.setAttribute("style","display:block;width:0;height:0;border:0;visibility:hidden"),c.setAttribute("aria-hidden",!0)),c.src=a+"partytown-"+(t?"atomics.js?v=0.7.6":"sandbox-sw.html?"+Date.now()),e.body.appendChild(c)}function f(n,r){for(w(),i==t&&(o.forward||[]).map((function(e){delete t[e.split(".")[0]]})),n=0;n<s.length;n++)(r=e.createElement("script")).innerHTML=s[n].innerHTML,e.head.appendChild(r);c&&c.parentNode.removeChild(c)}function w(){clearTimeout(d)}o=t.partytown||{},i==t&&(o.forward||[]).map((function(e){p=t,e.split(".").map((function(e,n,i){p=p[i[n]]=n+1<i.length?"push"==i[n+1]?[]:p[i[n]]||{}:function(){(t._ptf=t._ptf||[]).push(i,arguments)}}))})),"complete"==e.readyState?u():(t.addEventListener("DOMContentLoaded",u),t.addEventListener("load",u))}(window,document,navigator,top,window.crossOriginIsolated);
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-MJNNBE6XYD" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    window.dataLayer = window.dataLayer || [];
#           function gtag(){dataLayer.push(arguments);}
#           gtag('js', new Date());
#           gtag('config', 'G-MJNNBE6XYD');
#   </script>
#   <meta content="Texas International College" property="og:title"/>
#   <meta content="https://media.edusanjal.com/__sized__/cover_photo/texas-intl-cover-thumbnail-1400x280-70.jpg" property="og:image"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="https://edusanjal.com/college/texas-international-higher-secondary-school-and-college/" property="og:url"/>
#   <meta content="Texas International College is ideally situated at Mitrapark, Chabahil, Kathmandu, one of the prime location of Kathmandu Valley. It is a unit of Texas International Educ" name="description"/>
#   <meta content="Texas International College is ideally situated at Mitrapark, Chabahil, Kathmandu, one of the prime location of Kathmandu Valley. It is a unit of Texas International Educ" property="og:description"/>
#   <link href="https://edusanjal.com/college/texas-international-higher-secondary-school-and-college/" rel="canonical"/>
#   <script type="application/ld+json">
#    {"@type":"CollegeOrUniversity","@context":"https://schema.org","@id":"https://edusanjal.com/college/texas-international-higher-secondary-school-and-college/","url":"https://edusanjal.com/college/texas-international-higher-secondary-school-and-college/","image":"https://media.edusanjal.com/__sized__/cover_photo/texas-intl-cover-thumbnail-1400x280-70.jpg","name":"Texas International College","description":"Texas International College is ideally situated at Mitrapark, Chabahil, Kathmandu, one of the prime location of Kathmandu Valley. It is a unit of Texas International Education Network established in 2009. It is an academic institution run, managed and patronized by energetic educational professionals and experts having strong will to turn it into the first choice of quality-seeking and studious students.&nbsp; The motto of the college is 'Education for a complete human being' and the college commits to provide quality education at affordable fees. It caters quality education in Management, Science and Humanities streams. Texas International College offers B.Sc. CSIT, Bachelor of Business Studies (BBS), Bachelor of Business Management (BBM),Bachelor of Arts (BA), Bachelor of Arts in Social Works (BSW), Bachelor of Computer Applications (BCA), and Master of Business Studies (MBS)&nbsp;with the affiliation from Tribhuvan University. The main purpose of the college is to produce professionally sound, socially amiable and globally competent workforce for the global needs. Its main objective is to make students enrolled to be able to pursue their study uniquely, research brilliantly, interact sufficiently and enhance multicultural knowledge. The college has dedicated, experienced and efficient teaching faculties.&nbsp;&nbsp;"}
#   </script>
#   <link as="script" crossorigin="" href="/_nuxt/entry.602c7578.js" rel="modulepreload"/>
#   <link as="style" href="/_nuxt/entry.628cd079.css" rel="preload"/>
#   <link as="script" crossorigin="" href="/_nuxt/default.0786d130.js" rel="modulepreload"/>
#   <link as="style" href="/_nuxt/default.566fedd0.css" rel="preload"/>
#   <link as="script" crossorigin="" href="/_nuxt/nuxt-link.35454155.js" rel="modulepreload"/>
#   <link as="script" crossorigin="" href="/_nuxt/SearchFocus.19f2825b.js" rel="modulepreload"/>
#   <link as="style" href="/_nuxt/SearchFocus.20a31c64.css" rel="preload"/>
#   <link as="script" crossorigin="" href="/_nuxt/Icon.21205d39.js" rel="modulepreload"/>
#   <link as="script" crossorigin="" href="/_nuxt/config.8e8c9cee.js" rel="modulepreload"/>
#   <link as="script" crossorigin="" href="/_nuxt/index.937b760c.js" rel="modulepreload"/>
#   <link as="script" crossorigin="" href="/_nuxt/LoadingFiller.54bcb671.js" rel="modulepreload"/>
#   <link as="style" href="/_nuxt/LoadingFiller.a489b434.css" rel="preload"/>
#   <link as="script" crossorigin="" href="/_nuxt/Error.142dda43.js" rel="modulepreload"/>
#   <link as="script" crossorigin="" href="/_nuxt/MessageFromPersonnel.34831568.js" rel="modulepreload"/>
#   <link as="style" href="/_nuxt/MessageFromPersonnel.7d424c70.css" rel="preload"/>
#   <link as="script" crossorigin="" href="/_nuxt/activeScrollSection.1e1cee7d.js" rel="modulepreload"/>
#   <link as="script" crossorigin="" href="/_nuxt/client-only.7ee3e851.js" rel="modulepreload"/>
#   <link as="script" crossorigin="" href="/_nuxt/TextBlock.4c3a6dc3.js" rel="modulepreload"/>
#   <link as="script" crossorigin="" href="/_nuxt/PostBlock.ae2dd449.js" rel="modulepreload"/>
#   <link as="script" crossorigin="" href="/_nuxt/VacancyBlock.0365fbad.js" rel="modulepreload"/>
#   <link as="script" crossorigin="" href="/_nuxt/CoverCard.79d3e398.js" rel="modulepreload"/>
#   <link as="script" crossorigin="" href="/_nuxt/placeholders.43e8997d.js" rel="modulepreload"/>
#   <link as="script" crossorigin="" href="/_nuxt/Active.4aa4bc89.js" rel="modulepreload"/>
#   <link as="style" href="/_nuxt/Active.b7b3977e.css" rel="preload"/>
#   <link as="script" crossorigin="" href="/_nuxt/InArticleAd.728e0b54.js" rel="modulepreload"/>
#   <link as="script" crossorigin="" href="/_nuxt/useApi.61fdcd48.js" rel="modulepreload"/>
#   <link as="script" crossorigin="" href="/_nuxt/useOg.759cf64a.js" rel="modulepreload"/>
#   <link as="script" crossorigin="" href="/_nuxt/control.f9608212.js" rel="prefetch"/>
#   <link as="script" crossorigin="" href="/_nuxt/useToast.27a83fe9.js" rel="prefetch"/>
#   <link as="style" href="/_nuxt/error-component.a966d5d5.css" rel="prefetch"/>
#   <link as="script" crossorigin="" href="/_nuxt/error-component.bbca1c5b.js" rel="prefetch"/>
#   <link href="/_nuxt/entry.628cd079.css" rel="stylesheet"/>
#   <link href="/_nuxt/default.566fedd0.css" rel="stylesheet"/>
#   <link href="/_nuxt/SearchFocus.20a31c64.css" rel="stylesheet"/>
#   <link href="/_nuxt/LoadingFiller.a489b434.css" rel="stylesheet"/>
#   <link href="/_nuxt/MessageFromPersonnel.7d424c70.css" rel="stylesheet"/>
#   <link href="/_nuxt/Active.b7b3977e.css" rel="stylesheet"/>
#   <style>
#    .navbar-burger{color:#4a4a4a;cursor:pointer;display:block;height:1.5rem;margin-left:auto;position:relative;width:2rem}.navbar-burger span{background-color:currentColor;display:block;height:1px;left:calc(50% - 8px);position:absolute;transform-origin:center;transition-duration:86ms;transition-property:background-color,opacity,transform;transition-timing-function:ease-out;width:16px;width:1.2rem}.navbar-burger span:first-child{top:calc(50% - 6px)}.navbar-burger span:nth-child(2){top:calc(50% - 1px)}.navbar-burger span:nth-child(3){top:calc(50% + 4px)}.navbar-burger.is-active span:first-child{transform:translateY(5px) rotate(45deg)}.navbar-burger.is-active span:nth-child(2){opacity:0}.navbar-burger.is-active span:nth-child(3){transform:translateY(-5px) rotate(-45deg)}.menu .nuxt-link-exact-active{border-bottom:2px solid #18a0fb}.formkit-inner input[type=checkbox]{-webkit-appearance:none;-moz-appearance:none;-o-appearance:none;appearance:none;cursor:pointer;height:20px;outline:none;padding:2px;transition-duration:.3s;width:20px}.formkit-input+.formkit-decorator{background-color:none!important;border:1px solid #000;height:20px;width:20px}.formkit-inner input[type=checkbox]:checked+span:before{bottom:3px;content:"\1F5F8";display:block;left:3px;position:relative}
#   </style>
#   <style>
#    .fade-enter-active[data-v-c06f2523],.fade-leave-active[data-v-c06f2523]{transition:opacity .2s}.fade-enter[data-v-c06f2523],.fade-leave-to[data-v-c06f2523]{opacity:0}
#   </style>
#   <style>
#    .icon[data-v-cf1ec82f]{display:inline-block;vertical-align:middle}
#   </style>
#   <style>
#    img[data-v-5d0dbec3]{border:none}
#   </style>
#  </head>
#  <body>
#   <div id="__nuxt">
#    <div class="text-gray-700">
#     <div class="border-b-2 border-gray-100 md:px-8 md:pb-4 con sm-no-x-padding">
#      <div class="relative bg-white header">
#       <div class="flex justify-between items-center py-3">
#        <div class="-mr-2 -my-2 md:hidden">
#         <button aria-label="Open Menu" class="bg-white block rounded-md p-2" type="button">
#          <span class="sr-only">
#           Open menu
#          </span>
#          <a aria-label="menu" class="navbar-burger burger menu" role="button">
#           <span aria-hidden="true">
#           </span>
#           <span aria-hidden="true">
#           </span>
#           <span aria-hidden="true">
#           </span>
#          </a>
#          <div class="text-xxs">
#           MENU
#          </div>
#         </button>
#        </div>
#        <div class="flex justify-start lg:w-0 lg:flex-1">
#         <a class="" href="/">
#          <span class="sr-only">
#           Edusanjal
#          </span>
#          <img alt="Edusanjal" class="h-8 w-auto sm:h-10 md:block mw-40" data-not-lazy="" height="46" src="/edusanjal-logo.svg" width="300"/>
#         </a>
#        </div>
#        <div class="relative text-gray-600 mt-2 mx-auto hidden md:block w-96" data-v-c06f2523="">
#         <div data-v-6abd31f3="" data-v-c06f2523="">
#         </div>
#         <input class="border-2 border-gray-300 bg-white h-10 px-5 pr-16 rounded-lg text-sm outline-none focus:border-blue-500 w-full header-search-input" data-v-c06f2523="" name="search" placeholder="Search colleges, courses, schools ..." type="text" value=""/>
#         <button aria-label="Search" class="absolute right-0 top-0 mt-2 mr-4" data-v-c06f2523="" type="submit">
#          <svg aria-hidden="true" class="icon" data-v-c06f2523="" data-v-cf1ec82f="" height="1em" role="img" style="" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#           <path d="m19.6 21l-6.3-6.3q-.75.6-1.725.95T9.5 16q-2.725 0-4.612-1.888T3 9.5q0-2.725 1.888-4.612T9.5 3q2.725 0 4.612 1.888T16 9.5q0 1.1-.35 2.075T14.7 13.3l6.3 6.3l-1.4 1.4ZM9.5 14q1.875 0 3.188-1.313T14 9.5q0-1.875-1.313-3.188T9.5 5Q7.625 5 6.312 6.313T5 9.5q0 1.875 1.313 3.188T9.5 14Z" fill="currentColor">
#           </path>
#          </svg>
#         </button>
#         <!-- -->
#         <!-- -->
#        </div>
#        <div class="text-gray-600 md:hidden mr-2">
#         <button aria-label="Search">
#          <svg aria-hidden="true" class="icon" data-v-cf1ec82f="" height="1em" role="img" style="" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#           <path d="m19.6 21l-6.3-6.3q-.75.6-1.725.95T9.5 16q-2.725 0-4.612-1.888T3 9.5q0-2.725 1.888-4.612T9.5 3q2.725 0 4.612 1.888T16 9.5q0 1.1-.35 2.075T14.7 13.3l6.3 6.3l-1.4 1.4ZM9.5 14q1.875 0 3.188-1.313T14 9.5q0-1.875-1.313-3.188T9.5 5Q7.625 5 6.312 6.313T5 9.5q0 1.875 1.313 3.188T9.5 14Z" fill="currentColor">
#           </path>
#          </svg>
#         </button>
#        </div>
#        <div class="hidden md:flex items-center justify-end md:flex-1 lg:w-0">
#         <a class="whitespace-nowrap text-base font-medium text-gray-500 hover:text-gray-900" href="/account/login/">
#          Sign in
#         </a>
#         <a class="ml-8 whitespace-nowrap inline-flex items-center justify-center px-4 py-2 border border-transparent rounded-md shadow-sm text-base font-medium text-white bg-pr hover:bg-primary-light" href="/account/signup/">
#          Sign up
#         </a>
#        </div>
#       </div>
#       <div class="inset-x-0 transition transform origin-top-right md:hidden">
#        <!-- -->
#       </div>
#       <!-- -->
#      </div>
#      <nav class="hidden md:flex space-x-10 mb-1 mt-2 menu">
#       <a class="text-base font-medium text-gray-500 hover:text-gray-900" href="/course/">
#        Courses
#       </a>
#       <a class="text-base font-medium text-gray-500 hover:text-gray-900" href="/college/">
#        Colleges
#       </a>
#       <a class="text-base font-medium text-gray-500 hover:text-gray-900" href="/discipline/">
#        Disciplines
#       </a>
#       <a class="text-base font-medium text-gray-500 hover:text-gray-900" href="/school/">
#        Schools
#       </a>
#       <a class="text-base font-medium text-gray-500 hover:text-gray-900" href="/admission/">
#        Admissions
#       </a>
#       <a class="text-base font-medium text-gray-500 hover:text-gray-900" href="/news/">
#        News
#       </a>
#       <a class="text-base font-medium text-gray-500 hover:text-gray-900" href="/blog/">
#        Blogs
#       </a>
#       <div class="relative group">
#        <button class="group bg-white rounded-md text-gray-500 inline-flex items-center text-base font-medium hover:text-gray-900 focus:outline-none focus:ring-2 focus:ring-offset-2 focus:ring-blue-500" type="button">
#         <span>
#          More
#         </span>
#         <svg aria-hidden="true" class="ml-2 h-5 w-5 text-gray-400 group-hover:text-gray-500" fill="currentColor" viewbox="0 0 20 20" xmlns="http://www.w3.org/2000/svg">
#          <path clip-rule="evenodd" d="M5.293 7.293a1 1 0 011.414 0L10 10.586l3.293-3.293a1 1 0 111.414 1.414l-4 4a1 1 0 01-1.414 0l-4-4a1 1 0 010-1.414z" fill-rule="evenodd">
#          </path>
#         </svg>
#        </button>
#        <div class="group-hover:block absolute hidden pt-1 z-40 bg-gray-100" style="min-width:150px;">
#         <a class="hover:bg-gray-200 p-2 block" href="/school/">
#          Schools
#         </a>
#         <a class="hover:bg-gray-200 p-2 block" href="/scholarship/">
#          Scholarships
#         </a>
#         <a class="hover:bg-gray-200 p-2 block" href="/vacancy/">
#          Vacancies
#         </a>
#         <a class="hover:bg-gray-200 p-2 block" href="/career/">
#          Careers
#         </a>
#         <a class="hover:bg-gray-200 p-2 block" href="/event/">
#          Events
#         </a>
#         <a class="hover:bg-gray-200 p-2 block" href="/watch/">
#          Videos
#         </a>
#         <a class="hover:bg-gray-200 p-2 block" href="/ranking/">
#          Rankings
#         </a>
#         <a class="hover:bg-gray-200 p-2 block" href="/post/">
#          Posts
#         </a>
#         <a class="hover:bg-gray-200 p-2 block" href="/council/">
#          Councils
#         </a>
#         <a class="hover:bg-gray-200 p-2 block" href="/organization/">
#          Organizations
#         </a>
#         <a class="hover:bg-gray-200 p-2 block" href="/university/">
#          Universities
#         </a>
#        </div>
#       </div>
#      </nav>
#     </div>
#     <!--[-->
#     <div>
#      <div>
#       <div>
#        <div class="bg-gray-100">
#         <img class="object-scale-down w-full mh-300" sizes="
#           (min-width: 1510px) 2000px,
#           (min-width: 1410px) 1500px,
#           (min-width: 1410px) 1500px,
#           (min-width: 1210px) 1400px,
#           (min-width: 910px) 1200px,
#           (min-width: 610px) 900px,
#           (min-width: 405px) 600px
#           100vw" src="https://media.edusanjal.com/__sized__/cover_photo/texas-intl-cover-thumbnail-1400x280-70.jpg" srcset="
#               https://media.edusanjal.com/__sized__/cover_photo/texas-intl-cover-thumbnail-2000x400-70.jpg 2000w,
#               https://media.edusanjal.com/__sized__/cover_photo/texas-intl-cover-thumbnail-1500x300-70.jpg 1500w,
#               https://media.edusanjal.com/__sized__/cover_photo/texas-intl-cover-thumbnail-1400x280-70.jpg 1400w,
#               https://media.edusanjal.com/__sized__/cover_photo/texas-intl-cover-thumbnail-1200x240-70.jpg 1200w,
#               https://media.edusanjal.com/__sized__/cover_photo/texas-intl-cover-thumbnail-900x180-70.jpg 900w,
#               https://media.edusanjal.com/__sized__/cover_photo/texas-intl-cover-thumbnail-600x120-70.jpg 600w,
#               https://media.edusanjal.com/__sized__/cover_photo/texas-intl-cover-thumbnail-400x80-70.jpg 400w,
#           "/>
#        </div>
#        <div class="sticky top-0 bg-gray-100 z-20 shadow-xl">
#         <div class="con grid grid-cols-10 -mb-36 sm-no-x-padding gap-2">
#          <div class="lg:-mt-8 text-center col-span-2">
#           <!--[-->
#           <img class="max-h-48 mb-1 md:-mb-8 rounded-r-3xl md:shadow-xl p-4 md:bg-white" src="https://media.edusanjal.com/__sized__/logos/logo-02-thumbnail-200x200.png"/>
#           <!--]-->
#           <div class="text-lg px-3 bg-pr hover:bg-primary-light text-white rounded-full inline md:hidden mt-8">
#            ✓
#           </div>
#          </div>
#          <div class="org-title col-span-8">
#           <h1 class="title-font text-xl md:text-4xl pb-1 md:pb-4 font-bold leading-5 py-4 z-20">
#            Texas International College
#            <div class="text-lg px-3 bg-pr hover:bg-primary-light text-white rounded-full hidden md:inline">
#             ✓
#            </div>
#           </h1>
#           <div class="md:flex justify-between">
#            <div class="text-base md:text-xl text-gray-600 leading-5 mb-2">
#             <span>
#              Mitrapark, Chabhil, Kathmandu
#             </span>
#            </div>
#            <a class="btn primary whitespace-nowrap md:-mt-4 mb-2 inline-block" href="/college/texas-international-higher-secondary-school-and-college/query">
#             Ask a Question
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="con org-detail md:grid grid-cols-10">
#         <div class="col-span-2 pr-6 hidden md:block">
#          <div class="sticky top-40 org-left">
#           <div class="min-h-48 mt-40">
#           </div>
#           <ul class="flex flex-col py-4 rounded-r-3xl text-sm font-medium text-gray-500">
#            <li>
#             <a class="hover-item detect" href="#about">
#              About
#             </a>
#            </li>
#            <!-- -->
#            <li>
#             <a class="hover-item detect" href="#programs">
#              Offered Programs
#              <span class="ml-auto mr-6 text-xs bg-gray-200 rounded-full px-3 py-px text-pr">
#               7
#              </span>
#             </a>
#            </li>
#            <li>
#             <a class="hover-item detect" href="#salient_features">
#              Salient Features
#             </a>
#            </li>
#            <li>
#             <a class="hover-item detect" href="#admission_guidelines">
#              Admission Guidelines
#             </a>
#            </li>
#            <!-- -->
#            <li>
#             <a class="hover-item detect" href="#gallery">
#              Gallery
#             </a>
#            </li>
#            <!--[-->
#            <li>
#             <a class="hover-item" href="#message-chairman-124">
#              <span>
#               Message from the
#               <span class="capitalize">
#                Chairman
#               </span>
#              </span>
#             </a>
#            </li>
#            <!--]-->
#            <li>
#             <a class="hover-item" href="#news">
#              News
#             </a>
#            </li>
#            <!-- -->
#            <!-- -->
#            <!-- -->
#            <!-- -->
#            <li>
#             <a class="hover-item" href="#map">
#              Location
#             </a>
#            </li>
#            <!--[-->
#            <!--]-->
#           </ul>
#          </div>
#         </div>
#         <div class="main col-span-8 mt-40">
#          <div class="md:grid grid-cols-3 md:mr-4">
#           <div class="org-about col-span-2 text-justify text-gray-600 md:mr-4">
#            <div class="admissions mb-6" id="admissions">
#             <!--[-->
#             <!--]-->
#            </div>
#            <div class="prose max-w-none">
#            </div>
#            <div class="text-gray-500 normalize-headings">
#             <div>
#              <div class="text-left mt-4 box target" id="programs">
#               <h2 class="text-xl mb-4">
#                <a class="" href="/university/tribhuvan-university/">
#                 OFFERED PROGRAMS - Tribhuvan University
#                </a>
#               </h2>
#               <!--[-->
#               <div class="pb-2 mb-2 border-b last:border-b-0">
#                <div class="flex justify-between mb-1">
#                 <a class="font-bold" href="/college/texas-international-higher-secondary-school-and-college/program/bsc-computer-science-and-information-technology-bsc-csit-tribhuvan-university/">
#                  BSc Computer Science and Information Technology
#                  <span class="italic text-sm">
#                   (BScCSIT)
#                  </span>
#                 </a>
#                 <span class="text-xs">
#                  48 Seats
#                 </span>
#                </div>
#                <!-- -->
#                <!-- -->
#                <!-- -->
#               </div>
#               <div class="pb-2 mb-2 border-b last:border-b-0">
#                <div class="flex justify-between mb-1">
#                 <a class="font-bold" href="/college/texas-international-higher-secondary-school-and-college/program/bachelor-in-computer-application-bca-tribhuvan-university/">
#                  Bachelor of Computer Application
#                  <span class="italic text-sm">
#                   (BCA)
#                  </span>
#                 </a>
#                 <span class="text-xs">
#                  35 Seats
#                 </span>
#                </div>
#                <!-- -->
#                <!-- -->
#                <!-- -->
#               </div>
#               <div class="pb-2 mb-2 border-b last:border-b-0">
#                <div class="flex justify-between mb-1">
#                 <a class="font-bold" href="/college/texas-international-higher-secondary-school-and-college/program/bachelor-of-business-studies-bbs-tribhuvan-university/">
#                  Bachelor of Business Studies
#                  <span class="italic text-sm">
#                   (BBS)
#                  </span>
#                 </a>
#                 <!-- -->
#                </div>
#                <!-- -->
#                <!-- -->
#                <!-- -->
#               </div>
#               <div class="pb-2 mb-2 border-b last:border-b-0">
#                <div class="flex justify-between mb-1">
#                 <a class="font-bold" href="/college/texas-international-higher-secondary-school-and-college/program/bachelor-of-social-works-bsw-tribhuvan-university/">
#                  Bachelor of Arts in Social Work
#                  <span class="italic text-sm">
#                   (BASW)
#                  </span>
#                 </a>
#                 <!-- -->
#                </div>
#                <!-- -->
#                <!-- -->
#                <!-- -->
#               </div>
#               <div class="pb-2 mb-2 border-b last:border-b-0">
#                <div class="flex justify-between mb-1">
#                 <a class="font-bold" href="/college/texas-international-higher-secondary-school-and-college/program/bachelor-of-business-management-bbm-tribhuvan-university/">
#                  Bachelor of Business Management
#                  <span class="italic text-sm">
#                   (BBM)
#                  </span>
#                 </a>
#                 <!-- -->
#                </div>
#                <!-- -->
#                <!-- -->
#                <!-- -->
#               </div>
#               <div class="pb-2 mb-2 border-b last:border-b-0">
#                <div class="flex justify-between mb-1">
#                 <a class="font-bold" href="/course/bachelor-of-arts-ba-tribhuvan-university/">
#                  Bachelor of Arts
#                  <span class="italic text-sm">
#                   (BA)
#                  </span>
#                 </a>
#                 <!-- -->
#                </div>
#                <!-- -->
#                <!-- -->
#                <!-- -->
#               </div>
#               <div class="pb-2 mb-2 border-b last:border-b-0">
#                <div class="flex justify-between mb-1">
#                 <a class="font-bold" href="/course/master-of-business-studies-mbs-tribhuvan-university/">
#                  Master of Business Studies
#                  <span class="italic text-sm">
#                   (MBS)
#                  </span>
#                 </a>
#                 <!-- -->
#                </div>
#                <!-- -->
#                <!-- -->
#                <!-- -->
#               </div>
#               <!--]-->
#              </div>
#             </div>
#             <div class="mt-6" id="salient_features">
#              <h2 class="text-xl text-gray-800 mb-4 uppercase">
#               Salient Features
#              </h2>
#              <div class="prose max-w-none text-gray-600">
#               <p>
#                <strong>
#                 Project Work and Field Visit
#                </strong>
#               </p>
#               <p>
#                The college conducts project work, seminar and field visit to expose students to the practical knowledge.
#               </p>
#               <p>
#                <strong>
#                 Library
#                </strong>
#               </p>
#               <p>
#                Students can enjoy the facilities of library as there are a good resources and materials, books,journals,magazines and newspapers.
#               </p>
#               <p>
#                <strong>
#                 Labs
#                </strong>
#               </p>
#               <p>
#                The college has well-equipped physics, chemistry, biology labs with availability of all required equipment. Students can do research work in a spacious computer lab.
#               </p>
#               <p>
#                <strong>
#                 Assessments
#                </strong>
#               </p>
#               <p>
#                Only through assessment, an individual’s capability is known. Thus, the college conducts internal assessment tests to find out potentiality of students. The college provide the facilities of re exams those who could not perform well in the internal assessment.
#               </p>
#               <p>
#                <strong>
#                 Sports and Cultural Programs
#                </strong>
#               </p>
#               <p>
#                The college conduct various games and sports for the students to participate. The students enjoy activities such as basketball, volleyball, table-tennis, badminton,etc. In addition, it also organize cultural programs
#               </p>
#               <p>
#                <strong>
#                 Transportation
#                </strong>
#               </p>
#               <p>
#                Students who wish to receive the college transportation facility, there is the services.
#               </p>
#               <p>
#                <strong>
#                 Social Service
#                </strong>
#               </p>
#               <p>
#                Texas College encourages students to engage in various social service campaigns like blood donation, youth rehabilitation, cleaning campaign, traffic awareness campaign, charity and donation to make them socially responsible.
#               </p>
#              </div>
#             </div>
#             <hr class="mt-4"/>
#             <div class="mt-6" id="admission_guidelines">
#              <h2 class="text-xl text-gray-800 mb-4 uppercase">
#               Admission Guidelines
#              </h2>
#              <div class="prose max-w-none text-gray-600">
#               <p>
#                <strong>
#                 For B.Sc. CSIT:
#                </strong>
#               </p>
#               <p>
#                The student should have secured at least C in all subjects in Grade 11 and Grade 12  by taking Physics and Mathematics of 100 marks.
#               </p>
#               <p>
#                <strong>
#                 For BASW, BA, BBM, BBS, BCA:
#                </strong>
#               </p>
#               <p>
#                The student must have secured at least D+ in all subjects in Grade 11 and Grade 12.
#               </p>
#               <p>
#                <strong>
#                 For MBS:
#                </strong>
#               </p>
#               <p>
#                The student applying for admission to to MBS course must have successfully completed the BBS program or a bachelor degree on any discipline from Tribhuvan University or from any other university recognized by Tribhuvan University.
#               </p>
#              </div>
#             </div>
#             <!-- -->
#            </div>
#           </div>
#           <div class="org-right col-span-1 md:ml-6 mt-2 font-medium">
#            <!-- -->
#            <ul class="flex flex-col bg-gray-100 pt-8 rounded-r-2xl text-sm text-gray-500">
#             <!--[-->
#             <li title="Accreditation">
#              <a class="flex hover:text-gray-800" href="/university/tribhuvan-university/">
#               <span class="inline-flex justify-center h-12 w-12 text-lg">
#                <svg aria-hidden="true" class="icon" data-v-cf1ec82f="" height="1em" role="img" style="" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                 <path d="M21 10a1 1 0 0 0 1-1V6a.999.999 0 0 0-.684-.948l-9-3a1.002 1.002 0 0 0-.632 0l-9 3A.999.999 0 0 0 2 6v3a1 1 0 0 0 1 1h1v7.184A2.995 2.995 0 0 0 2 20v2a1 1 0 0 0 1 1h18a1 1 0 0 0 1-1v-2a2.995 2.995 0 0 0-2-2.816V10Zm-1 11H4v-1a1.001 1.001 0 0 1 1-1h14a1.001 1.001 0 0 1 1 1ZM6 17v-7h2v7Zm4 0v-7h4v7Zm6 0v-7h2v7ZM4 8V6.72l8-2.666l8 2.667V8Z" fill="currentColor">
#                 </path>
#                </svg>
#               </span>
#               <span>
#                Tribhuvan University
#               </span>
#              </a>
#             </li>
#             <!--]-->
#             <!-- -->
#             <li title="Established">
#              <span class="flex text-gray-500 hover:text-gray-800">
#               <span class="inline-flex justify-center h-12 w-12 text-lg">
#                <svg aria-hidden="true" class="icon" data-v-cf1ec82f="" height="1em" role="img" style="" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                 <path d="M19 4h-1V2h-2v2H8V2H6v2H5c-1.11 0-1.99.9-1.99 2L3 20a2 2 0 0 0 2 2h14c1.1 0 2-.9 2-2V6c0-1.1-.9-2-2-2zm0 16H5V10h14v10zM9 14H7v-2h2v2zm4 0h-2v-2h2v2zm4 0h-2v-2h2v2zm-8 4H7v-2h2v2zm4 0h-2v-2h2v2zm4 0h-2v-2h2v2z" fill="currentColor">
#                 </path>
#                </svg>
#               </span>
#               <span class="text-sm">
#                Established 2009 AD
#               </span>
#              </span>
#             </li>
#             <li title="Ownership">
#              <span class="flex hover:text-gray-800 capitalize">
#               <span class="inline-flex justify-center h-12 w-12 text-lg">
#                <svg aria-hidden="true" class="icon" data-v-cf1ec82f="" height="1em" role="img" style="" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                 <path d="M3 21h18M9 8h1m-1 4h1m-1 4h1m4-8h1m-1 4h1m-1 4h1M5 21V5a2 2 0 0 1 2-2h10a2 2 0 0 1 2 2v16" fill="none" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2">
#                 </path>
#                </svg>
#               </span>
#               private Institution
#              </span>
#             </li>
#             <li title="Phone">
#              <span class="flex hover:text-gray-800">
#               <span class="inline-flex justify-center h-12 w-12 text-lg">
#                <svg aria-hidden="true" class="icon" data-v-cf1ec82f="" height="1em" role="img" style="" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                 <path d="M6.54 5c.06.89.21 1.76.45 2.59l-1.2 1.2c-.41-1.2-.67-2.47-.76-3.79h1.51m9.86 12.02c.85.24 1.72.39 2.6.45v1.49c-1.32-.09-2.59-.35-3.8-.75l1.2-1.19M7.5 3H4c-.55 0-1 .45-1 1c0 9.39 7.61 17 17 17c.55 0 1-.45 1-1v-3.49c0-.55-.45-1-1-1c-1.24 0-2.45-.2-3.57-.57a.84.84 0 0 0-.31-.05c-.26 0-.51.1-.71.29l-2.2 2.2a15.149 15.149 0 0 1-6.59-6.59l2.2-2.2c.28-.28.36-.67.25-1.02A11.36 11.36 0 0 1 8.5 4c0-.55-.45-1-1-1z" fill="currentColor">
#                 </path>
#                </svg>
#               </span>
#               <span>
#                01-4579017, 01-4490670, 01-4488627
#               </span>
#              </span>
#             </li>
#             <li title="Email">
#              <span class="flex hover:text-gray-800">
#               <span class="inline-flex justify-center h-12 w-12 text-lg">
#                <svg aria-hidden="true" class="icon" data-v-cf1ec82f="" height="1em" role="img" style="" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                 <path d="M21 3a1 1 0 0 1 1 1v16.007a1 1 0 0 1-.992.993H2.992A.993.993 0 0 1 2 20.007V19h18V7.3l-8 7.2l-10-9V4a1 1 0 0 1 1-1h18ZM8 15v2H0v-2h8Zm-3-5v2H0v-2h5Zm14.566-5H4.434L12 11.81L19.566 5Z" fill="currentColor">
#                 </path>
#                </svg>
#               </span>
#               <span>
#                enquiry@texasintl.edu.np
#               </span>
#              </span>
#             </li>
#             <li>
#              <span class="flex items-center">
#               <a class="inline-flex justify-center h-12 w-12 text-lg hover:text-gray-800" href="http://www.texasintl.edu.np/" rel="noopener noreferrer nofollow" target="_blank" title="Website">
#                <svg aria-hidden="true" class="icon" data-v-cf1ec82f="" height="1em" role="img" style="" viewbox="0 0 256 256" width="1em" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                 <path d="M128 20a108 108 0 1 0 108 108A108.12 108.12 0 0 0 128 20Zm83.13 96h-31.57a155.5 155.5 0 0 0-19.51-65.63A84.23 84.23 0 0 1 211.13 116Zm-110.62 24h55c-2.25 26.69-12 51.46-27.49 69.85c-15.56-18.39-25.26-43.16-27.51-69.85Zm0-24c2.25-26.69 11.95-51.46 27.49-69.85c15.54 18.39 25.24 43.16 27.49 69.85ZM96 50.37A155.5 155.5 0 0 0 76.44 116H44.87A84.23 84.23 0 0 1 96 50.37ZM44.87 140h31.57A155.5 155.5 0 0 0 96 205.63A84.23 84.23 0 0 1 44.87 140Zm115.18 65.63A155.5 155.5 0 0 0 179.56 140h31.57a84.23 84.23 0 0 1-51.08 65.63Z" fill="currentColor">
#                 </path>
#                </svg>
#               </a>
#               <a class="inline-flex justify-center h-12 w-12 text-lg hover:text-gray-800" href="https://www.google.com/maps/?q=27.71349,85.34517" rel="noopener noreferrer" target="_blank" title="Map">
#                <svg aria-hidden="true" class="icon" data-v-cf1ec82f="" height="1em" role="img" style="" viewbox="0 0 256 256" width="1em" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                 <path d="M128 64a40 40 0 1 0 40 40a40 40 0 0 0-40-40Zm0 64a24 24 0 1 1 24-24a24 24 0 0 1-24 24Zm0-112a88.1 88.1 0 0 0-88 88c0 31.4 14.51 64.68 42 96.25a254.19 254.19 0 0 0 41.45 38.3a8 8 0 0 0 9.18 0a254.19 254.19 0 0 0 41.37-38.3c27.45-31.57 42-64.85 42-96.25a88.1 88.1 0 0 0-88-88Zm0 206c-16.53-13-72-60.75-72-118a72 72 0 0 1 144 0c0 57.23-55.47 105-72 118Z" fill="currentColor">
#                 </path>
#                </svg>
#               </a>
#               <a class="inline-flex justify-center h-12 w-12 text-lg hover:text-gray-800" href="#gallery" title="Gallery">
#                <svg aria-hidden="true" class="icon" data-v-cf1ec82f="" height="1em" role="img" style="" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                 <path d="M19 5v14H5V5h14m0-2H5c-1.1 0-2 .9-2 2v14c0 1.1.9 2 2 2h14c1.1 0 2-.9 2-2V5c0-1.1-.9-2-2-2zm-4.86 8.86l-3 3.87L9 13.14L6 17h12l-3.86-5.14z" fill="currentColor">
#                 </path>
#                </svg>
#               </a>
#               <!-- -->
#              </span>
#             </li>
#            </ul>
#            <div id="videos">
#             <!-- -->
#            </div>
#            <div class="bg-gray-100 p-4 pb-0 rounded-r-2xl text-gray-500 text-justify mt-4" id="news">
#             <div class="flex justify-between">
#              <h2 class="text-xl">
#               <a class="" href="/news/">
#                News
#               </a>
#              </h2>
#             </div>
#             <ul class="grid divide-y text-sm">
#              <!--[-->
#              <li class="py-4">
#               <a class="" href="/news/texas-students-win-gold-medal-in-computer-science-category-at-young-scientists-summit/">
#                Texas Students Win Gold Medal in Computer Science Category at 7th Young Scientists Summit
#               </a>
#              </li>
#              <li class="py-4">
#               <a class="" href="/news/gbs-team-fpv-ground-race-competition/">
#                GBS Team FPV Ground Race Competition
#               </a>
#              </li>
#              <!--]-->
#             </ul>
#            </div>
#            <div class="bg-gray-100 p-4 pb-0 rounded-r-2xl text-gray-500 text-justify mt-4" id="posts">
#             <div class="flex justify-between">
#              <h2 class="text-xl">
#               <a class="" href="/post/">
#                Posts
#               </a>
#              </h2>
#             </div>
#             <ul class="grid divide-y text-sm">
#              <!--[-->
#              <li class="py-4">
#               <a class="" href="/post/texas-management-it-fair-2022/">
#                Texas Management &amp; IT Fair 2022
#               </a>
#              </li>
#              <li class="py-4">
#               <a class="" href="/post/eca-meet-at-texas/">
#                ECA Meet at Texas
#               </a>
#              </li>
#              <!--]-->
#             </ul>
#            </div>
#            <!-- -->
#            <!-- -->
#            <!-- -->
#            <!-- -->
#            <hr class="my-4"/>
#            <div class="mt-4" id="map">
#             <h2 class="text-xl mb-4">
#              Get Directions
#             </h2>
#             <a href="https://www.google.com/maps/?q=27.71349,85.34517" target="_blank" title="Get Directions in Map">
#              <img alt="Map for Texas International College" src="https://maps.googleapis.com/maps/api/staticmap?center=27.71349,85.34517&amp;zoom=13&amp;maptype=roadmap%20&amp;markers=label:%7CTexas International College&amp;size=320x405&amp;key=AIzaSyD2VKeIW2TaXMEfRcK2Is5cB60ewLiguj4"/>
#             </a>
#            </div>
#            <div>
#             <h2 class="text-xl my-8">
#              NETWORK INSTITUTIONS
#             </h2>
#             <!--[-->
#             <div class="overflow-hidden bg-white rounded shadow-xl mb-4">
#              <a class="" href="/school/texas-international-secondary-school/">
#               <img alt="Texas International Secondary School" class="object-cover w-full h-32" src="https://media.edusanjal.com/__sized__/cover_photo/texas-sec-scool-cover2-crop-c0-5__0-5-302x128-70.jpg"/>
#              </a>
#              <div class="p-5 pb-0">
#               <a class="text-2xl font-bold leading-7" href="/school/texas-international-secondary-school/">
#                Texas International Secondary School
#               </a>
#               <ul class="flex flex-col pt-4 rounded-r-2xl text-sm text-gray-500">
#                <li class="mt-2 mb-4" title="Address">
#                 <span class="flex hover:text-gray-800">
#                  <span class="inline-flex text-lg">
#                   <svg aria-hidden="true" class="icon" data-v-cf1ec82f="" height="1em" role="img" style="" viewbox="0 0 256 256" width="1em" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                    <path d="M128 64a40 40 0 1 0 40 40a40 40 0 0 0-40-40Zm0 64a24 24 0 1 1 24-24a24 24 0 0 1-24 24Zm0-112a88.1 88.1 0 0 0-88 88c0 31.4 14.51 64.68 42 96.25a254.19 254.19 0 0 0 41.45 38.3a8 8 0 0 0 9.18 0a254.19 254.19 0 0 0 41.37-38.3c27.45-31.57 42-64.85 42-96.25a88.1 88.1 0 0 0-88-88Zm0 206c-16.53-13-72-60.75-72-118a72 72 0 0 1 144 0c0 57.23-55.47 105-72 118Z" fill="currentColor">
#                    </path>
#                   </svg>
#                  </span>
#                  <span class="ml-2">
#                   Mitrapark, Chabahil, Kathmandu
#                  </span>
#                 </span>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="overflow-hidden bg-white rounded shadow-xl mb-4">
#              <a class="" href="/college/texas-international-college-management-and-it/">
#               <img alt="Texas College of Management and IT" class="object-cover w-full h-32" src="https://media.edusanjal.com/__sized__/cover_photo/TCMIT-Banner1-crop-c0-5__0-5-302x128-70.jpg"/>
#              </a>
#              <div class="p-5 pb-0">
#               <a class="text-2xl font-bold leading-7" href="/college/texas-international-college-management-and-it/">
#                Texas College of Management and IT
#               </a>
#               <ul class="flex flex-col pt-4 rounded-r-2xl text-sm text-gray-500">
#                <li class="mt-2 mb-4" title="Address">
#                 <span class="flex hover:text-gray-800">
#                  <span class="inline-flex text-lg">
#                   <svg aria-hidden="true" class="icon" data-v-cf1ec82f="" height="1em" role="img" style="" viewbox="0 0 256 256" width="1em" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                    <path d="M128 64a40 40 0 1 0 40 40a40 40 0 0 0-40-40Zm0 64a24 24 0 1 1 24-24a24 24 0 0 1-24 24Zm0-112a88.1 88.1 0 0 0-88 88c0 31.4 14.51 64.68 42 96.25a254.19 254.19 0 0 0 41.45 38.3a8 8 0 0 0 9.18 0a254.19 254.19 0 0 0 41.37-38.3c27.45-31.57 42-64.85 42-96.25a88.1 88.1 0 0 0-88-88Zm0 206c-16.53-13-72-60.75-72-118a72 72 0 0 1 144 0c0 57.23-55.47 105-72 118Z" fill="currentColor">
#                    </path>
#                   </svg>
#                  </span>
#                  <span class="ml-2">
#                   Siphal, Kathmandu
#                  </span>
#                 </span>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <!--]-->
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="text-center p-4 bg-gray-300 mt-8" id="gallery">
#         <h2 class="text-xl mb-4">
#          Gallery
#         </h2>
#         <div class="flex flex-wrap justify-center">
#          <!--[-->
#          <a title="">
#           <img alt="Image" class="border-4 border-white mr-1 cursor-pointer" src="https://media.edusanjal.com/__sized__/gallery/texas-international-college-3-crop-c0-5__0-5-180x120-70.jpg"/>
#          </a>
#          <a title="">
#           <img alt="Image" class="border-4 border-white mr-1 cursor-pointer" src="https://media.edusanjal.com/__sized__/gallery/Texas-International-College-crop-c0-5__0-5-180x120-70.jpg"/>
#          </a>
#          <a title="">
#           <img alt="Image" class="border-4 border-white mr-1 cursor-pointer" src="https://media.edusanjal.com/__sized__/gallery/texas-international-college-1-crop-c0-5__0-5-180x120-70.jpg"/>
#          </a>
#          <a title="">
#           <img alt="Image" class="border-4 border-white mr-1 cursor-pointer" src="https://media.edusanjal.com/__sized__/gallery/texas-college-study-crop-c0-5__0-5-180x120-70.jpg"/>
#          </a>
#          <a title="">
#           <img alt="Image" class="border-4 border-white mr-1 cursor-pointer" src="https://media.edusanjal.com/__sized__/gallery/Texas-college-students-crop-c0-5__0-5-180x120-70.jpg"/>
#          </a>
#          <a title="">
#           <img alt="Image" class="border-4 border-white mr-1 cursor-pointer" src="https://media.edusanjal.com/__sized__/gallery/Texas-College-Sports-crop-c0-5__0-5-180x120-70.jpg"/>
#          </a>
#          <a title="">
#           <img alt="Image" class="border-4 border-white mr-1 cursor-pointer" src="https://media.edusanjal.com/__sized__/gallery/texas-college-library-crop-c0-5__0-5-180x120-70.jpg"/>
#          </a>
#          <a title="">
#           <img alt="Image" class="border-4 border-white mr-1 cursor-pointer" src="https://media.edusanjal.com/__sized__/gallery/Texas-College-Lab-crop-c0-5__0-5-180x120-70.jpg"/>
#          </a>
#          <a title="">
#           <img alt="Image" class="border-4 border-white mr-1 cursor-pointer" src="https://media.edusanjal.com/__sized__/gallery/Texas-College-Classroom-crop-c0-5__0-5-180x120-70.jpg"/>
#          </a>
#          <a title="">
#           <img alt="Image" class="border-4 border-white mr-1 cursor-pointer" src="https://media.edusanjal.com/__sized__/gallery/Texas_international_school_building-crop-c0-5__0-5-180x120-70.jpg"/>
#          </a>
#          <!--]-->
#          <!-- -->
#         </div>
#        </div>
#        <div class="con md:grid grid-cols-4 mt-8">
#         <div class="content mt-4 col-span-3 pr-8">
#          <h2 class="text-2xl mb-4" id="about">
#           <span>
#            ABOUT US
#           </span>
#          </h2>
#          <div class="prose max-w-none text-gray-600">
#           <p>
#            Texas International College is ideally situated at Mitrapark, Chabahil, Kathmandu, one of the prime location of Kathmandu Valley. It is a unit of Texas International Education Network established in 2009. It is an academic institution run, managed and patronized by energetic educational professionals and experts having strong will to turn it into the first choice of quality-seeking and studious students.
#           </p>
#           <p>
#            The motto of the college is 'Education for a complete human being' and the college commits to provide quality education at affordable fees. It caters quality education in Management, Science and Humanities streams.
#           </p>
#           <p>
#            Texas International College offers
#            <strong>
#             B.Sc. CSIT
#            </strong>
#            , Bachelor of Business Studies
#            <strong>
#             (BBS)
#            </strong>
#            , Bachelor of Business Management
#            <strong>
#             (BBM)
#            </strong>
#            ,Bachelor of Arts
#            <strong>
#             (BA)
#            </strong>
#            , Bachelor of Arts in Social Works
#            <strong>
#             (BSW)
#            </strong>
#            , Bachelor of Computer Applications
#            <strong>
#             (BCA)
#            </strong>
#            , and Master of Business Studies
#            <strong>
#             (MBS)
#            </strong>
#            with the affiliation from Tribhuvan University.
#           </p>
#           <p>
#            The main purpose of the college is to produce professionally sound, socially amiable and globally competent workforce for the global needs. Its main objective is to make students enrolled to be able to pursue their study uniquely, research brilliantly, interact sufficiently and enhance multicultural knowledge. The college has dedicated, experienced and efficient teaching faculties.
#           </p>
#          </div>
#         </div>
#         <div>
#          <!--[-->
#          <div class="bg-gray-100 p-4 pb-0 rounded-r-2xl text-gray-500 con mb-4" data-v-5613b9af="">
#           <span data-v-5613b9af="" id="message-chairman-124">
#           </span>
# ...
#              Campus Chief
#             </div>
#            </div>
#           </div>
#          </div>
#          <!--]-->
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!--]-->
#     <hr class="mt-8"/>
#     <div class="flex w-full bg-white">
#      <footer class="w-full bg-gray-100">
#       <div>
#        <div class="flex flex-col md:flex-row justify-center w-full mt-12 px-2 mx-auto text-center items-center gap-4" data-v-5d0dbec3="">
#         <a data-v-5d0dbec3="" href="https://play.google.com/store/apps/details?id=com.awecode.edusanjal" rel="noopener" target="_blank">
#          <img alt="Google Play" class="h-16" data-v-5d0dbec3="" height="101" src="/img/google-play.svg" width="300"/>
#         </a>
#         <a data-v-5d0dbec3="" href="https://apps.apple.com/app/edusanjal/id1573813757" rel="noopener" target="_blank">
#          <img alt="Apple App Store" class="h-16" data-v-5d0dbec3="" height="101" src="/img/app-store.svg" width="300"/>
#         </a>
#         <!-- -->
#        </div>
#       </div>
#       <div class="con px-5 py-12 flex flex-wrap w-full">
#        <div class="text-center mx-auto mb-4">
#         <a class="flex items-center justify-center" href="/">
#          <img alt="Edusanjal" class="h-8 w-auto md:block mw-40" height="46" src="/edusanjal-logo.svg" width="300"/>
#         </a>
#         <p class="mt-2 text-sm">
#          Your Guide to Education in Nepal!
#         </p>
#         <div class="mt-4">
#          <span class="inline-flex justify-center mt-2 sm:ml-auto sm:mt-0 sm:justify-start">
#           <a class="hover:text-gray-700" href="https://www.facebook.com/edusanjal" rel="noopener" target="_blank" title="Facebook">
#            <svg class="w-5 h-5" fill="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24">
#             <path d="M18 2h-3a5 5 0 00-5 5v3H7v4h3v8h4v-8h3l1-4h-4V7a1 1 0 011-1h3z">
#             </path>
#            </svg>
#           </a>
#           <a class="ml-3 hover:text-gray-700" href="https://twitter.com/edusanjal" rel="noopener" target="_blank" title="Twitter">
#            <svg class="w-5 h-5" fill="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24">
#             <path d="M23 3a10.9 10.9 0 01-3.14 1.53 4.48 4.48 0 00-7.86 3v1A10.66 10.66 0 013 4s-4 9 5 13a11.64 11.64 0 01-7 2c9 5 20 0 20-11.5a4.5 4.5 0 00-.08-.83A7.72 7.72 0 0023 3z">
#             </path>
#            </svg>
#           </a>
#           <a class="ml-3 hover:text-gray-700" href="https://www.instagram.com/edusanjal/" rel="noopener" target="_blank" title="Instagram">
#            <svg class="w-5 h-5" fill="none" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24">
#             <rect height="20" rx="5" ry="5" width="20" x="2" y="2">
#             </rect>
#             <path d="M16 11.37A4 4 0 1112.63 8 4 4 0 0116 11.37zm1.5-4.87h.01">
#             </path>
#            </svg>
#           </a>
#           <a class="ml-3 hover:text-gray-700" href="https://www.linkedin.com/company/edusanjal/" rel="noopener" target="_blank" title="LinkedIn">
#            <svg class="w-5 h-5" fill="currentColor" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="0" viewbox="0 0 24 24">
#             <path d="M16 8a6 6 0 016 6v7h-4v-7a2 2 0 00-2-2 2 2 0 00-2 2v7h-4v-7a6 6 0 016-6zM2 9h4v12H2z" stroke="none">
#             </path>
#             <circle cx="4" cy="4" r="2" stroke="none">
#             </circle>
#            </svg>
#           </a>
#           <a class="ml-3 hover:text-gray-700" href="https://t.me/edusanjal" rel="noopener" target="_blank" title="Telegram">
#            <svg aria-hidden="true" class="icon" data-v-cf1ec82f="" height="1em" role="img" style="" viewbox="0 0 256 256" width="1em" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#             <path d="M236.88 26.19a9 9 0 0 0-9.16-1.57L25.06 103.93a14.22 14.22 0 0 0 2.43 27.21L80 141.45V200a15.92 15.92 0 0 0 10 14.83a15.91 15.91 0 0 0 17.51-3.73l25.32-26.26L173 220a15.88 15.88 0 0 0 10.51 4a16.3 16.3 0 0 0 5-.79a15.85 15.85 0 0 0 10.67-11.63L239.77 35a9 9 0 0 0-2.89-8.81Zm-61.14 36l-89.59 64.16l-49.6-9.73ZM96 200v-47.48l24.79 21.74Zm87.53 8l-82.68-72.5l119-85.29Z" fill="currentColor">
#             </path>
#            </svg>
#           </a>
#           <a class="ml-3 hover:text-gray-700" href="https://www.youtube.com/edusanjal/?sub_confirmation=1" rel="noopener" target="_blank" title="YouTube">
#            <svg class="w-5 h-5" fill="currentColor" viewbox="0 0 576 512">
#             <path d="M549.655 124.083c-6.281-23.65-24.787-42.276-48.284-48.597C458.781 64 288 64 288 64S117.22 64 74.629 75.486c-23.497 6.322-42.003 24.947-48.284 48.597c-11.412 42.867-11.412 132.305-11.412 132.305s0 89.438 11.412 132.305c6.281 23.65 24.787 41.5 48.284 47.821C117.22 448 288 448 288 448s170.78 0 213.371-11.486c23.497-6.321 42.003-24.171 48.284-47.821c11.412-42.867 11.412-132.305 11.412-132.305s0-89.438-11.412-132.305zm-317.51 213.508V175.185l142.739 81.205l-142.739 81.201z">
#             </path>
#            </svg>
#           </a>
#          </span>
#         </div>
#         <hr class="my-8"/>
#        </div>
#        <div class="flex flex-wrap flex-grow -mb-10 text-center md:pl-20 md:mt-0 md:text-left">
#         <div class="w-full px-4 lg:w-1/4 md:w-1/2">
#          <h2 class="mb-3 text-sm font-medium tracking-widest text-gray-900 uppercase title-font">
#           INFORMATION
#          </h2>
#          <ul class="mb-10 list-none text-gray-600">
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="/faq/">
#             FAQs
#            </a>
#           </li>
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="/about/us/">
#             About Us
#            </a>
#           </li>
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="/vacancy/vacancy-for-sales-manager-at-edusanjal/">
#             Career Opportunities
#            </a>
#           </li>
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="/about/advertising-policy/">
#             Advertising Policy
#            </a>
#           </li>
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="/about/terms-of-use/">
#             Terms of Use
#            </a>
#           </li>
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="/about/privacy-policy/">
#             Privacy Policy
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="w-full px-4 lg:w-1/4 md:w-1/2">
#          <h2 class="mb-3 text-sm font-medium tracking-widest text-gray-900 uppercase title-font">
#           CLIENT PORTAL
#          </h2>
#          <ul class="mb-10 list-none text-gray-600">
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="/dashboard/" rel="noopener">
#             Dashboard
#            </a>
#           </li>
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="/about/payment-methods/">
#             Payment Methods
#            </a>
#           </li>
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="/about/membership-service/">
#             Membership Service
#            </a>
#           </li>
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="/about/pricing/">
#             Services and Pricing
#            </a>
#           </li>
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="/account/signup/institution/">
#             Promote Your College
#            </a>
#           </li>
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="/account/signup/institution/">
#             Promote Your School
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="w-full px-4 lg:w-1/4 md:w-1/2">
#          <h2 class="mb-3 text-sm font-medium tracking-widest text-gray-900 uppercase title-font">
#           LINKS
#          </h2>
#          <ul class="mb-10 list-none text-gray-600">
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="/bachelors/" rel="noopener">
#             Bachelors Portal
#            </a>
#           </li>
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="/masters/" rel="noopener">
#             Masters Portal
#            </a>
#           </li>
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="https://edupatra.com" rel="noopener" target="_blank">
#             Edupatra
#            </a>
#           </li>
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="/date-converter/">
#             Date Converter
#            </a>
#           </li>
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="/preeti-to-unicode/" rel="noopener">
#             Preeti to Unicode
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="w-full px-4 lg:w-1/4 md:w-1/2">
#          <h2 class="mb-3 text-sm font-medium tracking-widest text-gray-900 uppercase title-font">
#           Contact
#          </h2>
#          <ul class="mb-10 list-none text-gray-600">
#           <li class="mt-3">
#            <span class="hover:text-gray-900">
#             Edu Sanjal Pvt. Ltd.
#            </span>
#           </li>
#           <li class="mt-2">
#            <a class="hover:text-gray-900 text-sm" href="https://edusanjal.page.link/map" rel="noopener" target="_blank" title="Click for map">
#             Sahayoginagar, Koteshwar-32,
#            </a>
#           </li>
#           <li>
#            <a class="hover:text-gray-900" href="https://edusanjal.page.link/map" rel="noopener" target="_blank" title="Click for map">
#             Kathmandu, Nepal
#            </a>
#           </li>
#           <li class="mt-3">
#            <a class="hover:text-gray-900" href="tel:97714155052">
#             +977-1-4155052
#            </a>
#           </li>
#           <li>
#            <a class="hover:text-gray-900" href="mailto:info@edusanjal.com">
#             info@edusanjal.com
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#       <div class="bg-gray-200">
#        <div class="container px-5 py-4 mx-auto">
#         <p class="text-sm text-gray-700 text-center">
#          © 2022 Edu Sanjal Pvt. Ltd.,
#          <a href="https://awecode.com" rel="noopener noreferrer" target="_blank">
#           in technical collaboration with Awecode
#          </a>
#         </p>
#        </div>
#       </div>
#      </footer>
#     </div>
#    </div>
#   </div>
#   <script data-ssr="true" id="__NUXT_DATA__" type="application/json">
#    [["Reactive",1],{"data":2,"state":146,"_errors":171,"serverRendered":21},{"jQkTCB9RT6":3},{"title":4,"established":5,"short_name":6,"logo":7,"cover_image":8,"secondary_cover_image":6,"full_address":16,"phone":17,"email":18,"website":19,"type":20,"og_image":11,"is_premium":21,"description":22,"latitude":23,"longitude":24,"introduction":25,"salient_features":26,"admission_guidelines":27,"program_offerings":28,"scholarship_information":74,"is_verified":21,"active_admissions":75,"affiliations":81,"video_link":6,"youtube":6,"personnel_messages":84,"recent_news":92,"upcoming_events":96,"recent_awards":97,"recent_documents":98,"active_vacancies":105,"recent_images":106,"network_organizations":143,"recent_posts":144,"has_ugc_accreditation":79,"sub_pages":145},"People's Campus","2038 BS",null,"https://media.edusanjal.com/__sized__/logos/peoples_campus-thumbnail-200x200-70.jpg",{"detail_4xl":9,"detail_3xl":10,"detail_2xl":11,"detail_xl":12,"detail_md":13,"detail_sm":14,"detail_xs":15},"https://media.edusanjal.com/__sized__/cover_photo/Peoples_Campus_cover2-thumbnail-2000x400-70.jpg","https://media.edusanjal.com/__sized__/cover_photo/Peoples_Campus_cover2-thumbnail-1500x300-70.jpg","https://media.edusanjal.com/__sized__/cover_photo/Peoples_Campus_cover2-thumbnail-1400x280-70.jpg","https://media.edusanjal.com/__sized__/cover_photo/Peoples_Campus_cover2-thumbnail-1200x240-70.jpg","https://media.edusanjal.com/__sized__/cover_photo/Peoples_Campus_cover2-thumbnail-900x180-70.jpg","https://media.edusanjal.com/__sized__/cover_photo/Peoples_Campus_cover2-thumbnail-600x120-70.jpg","https://media.edusanjal.com/__sized__/cover_photo/Peoples_Campus_cover2-thumbnail-400x80-70.jpg","Paknajol, Kathmandu","01-4251412 | 01-4251990","info@peoplescampus.edu.np","http://www.peoplescampus.edu.np/","community",true,"\u003Cp>People’s Campus&nbsp;is located at Paknajol, Kathmandu with the main block of the campus consisting of more than 60 classrooms and spacious ground for outdoor games, parking, and other purposes. The campus building and the inner area cover more than four ropanies of land at the heart of the city in Paknajol, which makes the campus self-dependent regarding the need for infrastructure. Its peaceful atmosphere is conducive to learning and teaching.&nbsp;\u003C/p>\r\n\r\n\u003Cp>The campus is a pioneering and a leading community-based academic institution was established in 1981 AD by a group of educationist, academicians and key stakeholders in the field of education with the motto of enhancing quality education which is affordable to the wider society. People's Campus offers 10+2 in Management with the affiliation from National Examination Board (NEB) and BBA, BBM, BBS and MBS programs with the affiliation from Tribhuvan University.\u003C/p>\r\n\r\n\u003Cp>Along the changing pace and demand of time, the campus has been modifying and modernizing the teaching pedagogy and organizing various types of demand-driven training for the teachers. In order to strengthen the learner autonomy in the classroom and motivate the learners intrinsically, the campus organizes activities viz workshops, presentations, seminars, and well-modified lectures. People's campus combines academic excellence with an innovative and entrepreneurial approach to research supporting a culture that engages and challenges students and staff in their pursuit of learning.\u003C/p>\r\n\r\n\u003Cp>People's Campus ensures that students are prepared for employment, entrepreneurship, and opportunities when they graduate. One of the ways in which we do this is through the awards, which recognizes and reward students who have gained significant academic skills through curricular and extracurricular activities and help them develop skills successfully to be potential employees and employer. The evidence is People’s Campus has regularly been winning the prestigious “Nepal Chamber of Commerce Excellence Award” for securing the best result in the Management Education and TU topper award ...
#   </script>
#   <script>
#    window.__NUXT__={};window.__NUXT__.config={public:{baseURL:"https://eb.edusanjal.com/v1"},app:{baseURL:"/",buildAssetsDir:"/_nuxt/",cdnURL:""}}
#   </script>
#   <script crossorigin="" src="/_nuxt/entry.602c7578.js" type="module">
#   </script>
#   <script>
#    (function(){var js = "window['__CF$cv$params']={r:'7dbb12220c318e57',m:'_rJlxpu9NvwqxK_.chXFxShPzb5e1uMUOGM5esvWHAU-1687505900-0-AYiGzrutM8i8IaQ3r2asNDmdkGv6nZrVW9anBKKaPBGM'};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/invisible.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.nonce = '';_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();
#   </script>
#  </body>
# </html>

# %% [markdown]
# #### title

# %%
title_finder=soup.find('div',class_ = 'org-title')
title=soup.find('div',class_ = 'org-title').h1.text.strip()
title=title[:-2]

print(title)
# Out:
# People's Campus

# %% [markdown]
# #### address

# %%
address=title_finder.find('div',class_='text-base')
address_location = address.span.get_text() 
location=address_location.split(' ')
print(location)
# Out:
# ['Paknajol,', 'Kathmandu']

# %% [markdown]
# #### street line address

# %%
street_line_address=''.join(location)
print(street_line_address)

if len(location) > 2:    
    city=location[0]+location[1]
    district=location[2]
else:
    city=location[0]
    district=location[1]

#this is the city and the district
print(city)
print(district)
# Out:
# Paknajol,Kathmandu
# Paknajol,
# Kathmandu

# %% [markdown]
# #### latitide and longitde

# %%
direction=soup.find('div',id='map')
map_link = direction.find('a')['href']
coordinates = map_link.split('?q=')[1].split(',')
# print(map_link)
#this is the latitude and longitude
latitude = coordinates[0]
longitude = coordinates[1]
print(latitude,longitude)
# Out:
# 27.71631 85.30852

# %% [markdown]
# #### right column

# %%
right_column=soup.find('div',class_='org-right')

# %% [markdown]
# #### email

# %%
email_tag=right_column.find('li',title='Email')
#this is the email
email_element = email_tag.span.get_text()
print(email_element)
# Out:
# padmashreecollege@gmail.com

# %% [markdown]
# #### phone number

# %%
phone_tag=right_column.find('li',title='Phone')
#this is the phone element
phone_element = phone_tag.span.get_text().replace(',','|').replace('&','|').replace(' ','').split('|')
print(phone_element)
# Out:
# ['01-4112252', '01-4112403']

# %% [markdown]
# #### logo

# %%
logos=soup.select_one('img.max-h-48.mb-1.md\:-mb-8.rounded-r-3xl.md\:shadow-xl.p-4.md\:bg-white')['src']
print(logos)
# Out:
# https://media.edusanjal.com/__sized__/logos/Padmashree_New_Logo-thumbnail-200x200-70.jpg

# %% [markdown]
# #### cover image

# %%
coverimage=soup.select_one('img.object-scale-down.w-full.mh-300')['src']
print(coverimage)
# Out:
# https://media.edusanjal.com/__sized__/org_cover/Hoarding_2-thumbnail-1400x280-70.jpg

# %% [markdown]
# #### about

# %%
about_main=soup.select_one('.content.mt-4.col-span-3.pr-8')
#this is the about text
about_text=about_main.select_one('.prose.max-w-none.text-gray-600 ').text
print(about_text)
# Out:
# The college has well-equipped, well-furnished and spacious laboratories to facilitate the smooth conduct of practicals and research works. The library is full of books, magazines, journals and other reading materials. Besides, students can enjoy e-learning in the well-equipped computer laboratory with 24 hour internet facility which can be used by the students in the specified time. It has space big enough for games such as basketball, table tennis, etc. Various modern methods of teaching through LCD Projector, OHP, regular talk program, seminars, etc are common.
# Vision
#
# To emerge as the most preferred educational group with global recognition from developing competent and socially sensitive leaders committed to excellence.
#
# Mission
#
# To make incessant endeavor to translate our vision into a reality and achieve the following objectives
# To create world class facilities and ambiance for advanced level of teaching and practical training
# To develop students as global citizens with conscience, commitment and dedication
# To continuously grow and become fountain head among institutes of technical education in Nepal
# To strengthen industry - institute interface and promote entrepreneurial development activities
# To have collaboration with leading universities of the world with a view to provide opportunities to students for higher studies and seek placement avenues abroad
# To start new courses on emerging areas

# %% [markdown]
# #### website URL

# %%
url=right_column.select_one('a.inline-flex.justify-center.h-12.w-12.text-lg.hover\:text-gray-800')['href']
print(url)
# Out:
# http://www.padmashreecollege.edu.np/

# %% [markdown]
# #### established date

# %%
est_date=right_column.find('li',title='Established')
est_list= est_date.span.get_text().split(' ')
est=est_list[1]+' '+est_list[2]
print(est)
# Out:
# 2007 AD

# %% [markdown]
# #### ownership type

# %%
ownership_type_find=right_column.find('li',title='Ownership')
org_type= ownership_type_find.span.get_text()
print(org_type)
# Out:
#  private Institution

# %% [markdown]
# #### gallery

# %%
gallery_find = soup.find('div', id='gallery')
gallery_photos = gallery_find.find_all('img')
gallery = [photo['src'] for photo in gallery_photos]
print(gallery)
# Out:
# ['https://media.edusanjal.com/__sized__/gallery/Padmashree_Library-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Food_Preparation_Padmashree-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Culinary_design_Padmashree_International_College-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_6-crop-c0-5__0-5-180x120-70.jpg', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_4-crop-c0-5__0-5-180x120-70.jpg', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_BHM-crop-c0-5__0-5-180x120-70.jpg', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_Activities_4-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_Activities_3-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_Activities_2-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_Activities_1-crop-c0-5__0-5-180x120-70.jpg', 'https://media.edusanjal.com/__sized__/gallery/padmashree_lab-crop-c0-5__0-5-180x120-70.jpg', 'https://media.edusanjal.com/__sized__/gallery/padmashree_computer_lab-crop-c0-5__0-5-180x120-70.jpg', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_Class-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_BHM_Students-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_BHM_Bar-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_Convocation-crop-c0-5__0-5-180x120-70.JPG']

# %% [markdown]
# #### scholarship

# %%
scholarship_find=soup.find('div',id='scholarship_information')
try:

    scholarship_div=scholarship_find.select_one('.prose.max-w-none.text-gray-600').ul
    scholarship_items = [item.text.strip() for item in scholarship_div if item.text.strip()]
except:
    scholarship_items=[]
print(scholarship_items)
# Out:
# ['Entry Level Scholarships', 'Performance-based Scholarships']

# %% [markdown]
# #### affiliated to

# %%
affiliated=[]
universities = soup.select('li[title="Accreditation"]')
for university in universities:
    try:
        name = university.select_one('a > span:last-child').text.strip()
        affiliated.append(name)
    except:
        affiliated=[]
    
print(affiliated)
# Out:
# ['Tribhuvan University', 'Nilai University, Malaysia']

# %% [markdown]
# #### courses (not implemented yet)

# %%
course=soup.find('div',id='programs')
course_program=course.select('.pb-2.mb-2.border-b.last\:border-b-0')
print(course_program)
# Out:
# [<div class="pb-2 mb-2 border-b last:border-b-0"><div class="flex justify-between mb-1"><a class="font-bold" href="/college/padmashree-international-college/program/bachelor-of-information-technology-nilai-university-college-malaysia/">Bachelor of Information Technology <span class="italic text-sm">(BIT)</span></a><!-- --></div><div class="flex justify-between text-xs mb-1"><a class="" href="/university/nilai-university-college-malaysia/">Nilai University, Malaysia</a><!-- --></div><!-- --><div class="flex justify-between"><a class="btn primary text-center py-2 block text-xs px-2 font-normal" href="/college/padmashree-international-college/program/bachelor-of-information-technology-nilai-university-college-malaysia/apply"> APPLY NOW </a></div></div>, <div class="pb-2 mb-2 border-b last:border-b-0"><div class="flex justify-between mb-1"><a class="font-bold" href="/college/padmashree-international-college/program/ba-hons-in-business-and-hospitality-management-nilai-university-college-malaysia/">BA (Hons) in Business and Hospitality Management <span class="italic text-sm">(BABHM)</span></a><!-- --></div><div class="flex justify-between text-xs mb-1"><a class="" href="/university/nilai-university-college-malaysia/">Nilai University, Malaysia</a><!-- --></div><!-- --><div class="flex justify-between"><a class="btn primary text-center py-2 block text-xs px-2 font-normal" href="/college/padmashree-international-college/program/ba-hons-in-business-and-hospitality-management-nilai-university-college-malaysia/apply"> APPLY NOW </a></div></div>, <div class="pb-2 mb-2 border-b last:border-b-0"><div class="flex justify-between mb-1"><a class="font-bold" href="/college/padmashree-international-college/program/bachelor-in-computer-application-bca-tribhuvan-university/">Bachelor of Computer Application <span class="italic text-sm">(BCA)</span></a><!-- --></div><div class="flex justify-between text-xs mb-1"><a class="" href="/university/tribhuvan-university/">Tribhuvan University</a><span>35 Seats</span></div><!-- --><!-- --></div>, <div class="pb-2 mb-2 border-b last:border-b-0"><div class="flex justify-between mb-1"><a class="font-bold" href="/college/padmashree-international-college/program/btech-food-technology-tribhuvan-university/">Bachelor of Food Technology (BTech Food) <!-- --></a><!-- --></div><div class="flex justify-between text-xs mb-1"><a class="" href="/university/tribhuvan-university/">Tribhuvan University</a><span>24 Seats</span></div><!-- --><!-- --></div>]

# %% [markdown]
# #### dictionary creation

# %%
dict={
    'name':title,
    'address':
    {
        'country_name': 'Nepal',
        'city':city,
        'district':district,
        'street_line_address':street_line_address,
        'latitude':latitude,
        'longitude':longitude,
    },
    'email':email_element,
    'contact':phone_element,
    'logo':logos,
    'coverimage':coverimage,
    'about':about_text,
    'websiteURL':url,
    'established':est,
    'organization_type':org_type,
    'gallery':gallery,
    'scholarship':
    {
        'title':scholarship_items,
    },
    
}

print(dict)
# Out:
# {'name': "People's Campus ", 'address': {'country_name': 'Nepal', 'city': 'Paknajol,', 'district': 'Kathmandu', 'street_line_address': 'Paknajol,Kathmandu', 'latitude': '27.71631', 'longitude': '85.30852'}, 'email': 'padmashreecollege@gmail.com', 'contact': ['01-4112252', '01-4112403'], 'logo': 'https://media.edusanjal.com/__sized__/logos/Padmashree_New_Logo-thumbnail-200x200-70.jpg', 'coverimage': 'https://media.edusanjal.com/__sized__/org_cover/Hoarding_2-thumbnail-1400x280-70.jpg', 'about': 'The college has well-equipped, well-furnished and spacious laboratories to facilitate the smooth conduct of practicals and research works. The library is full of books, magazines, journals and other reading materials. Besides, students can enjoy e-learning in the well-equipped computer laboratory with 24 hour internet facility which can be used by the students in the specified time. It has space big enough for games such as basketball, table tennis, etc. Various modern methods of teaching through LCD Projector, OHP, regular talk program, seminars, etc are common.\nVision\n\nTo emerge as the most preferred educational group with global recognition from developing competent and socially sensitive leaders committed to excellence.\n\nMission\n\nTo make incessant endeavor to translate our vision into a reality and achieve the following objectives\nTo create world class facilities and ambiance for advanced level of teaching and practical training\nTo develop students as global citizens with conscience, commitment and dedication\nTo continuously grow and become fountain head among institutes of technical education in Nepal\nTo strengthen industry - institute interface and promote entrepreneurial development activities\nTo have collaboration with leading universities of the world with a view to provide opportunities to students for higher studies and seek placement avenues abroad\nTo start new courses on emerging areas\n', 'websiteURL': 'https://edusanjal.com/college/peoples-campus/', 'established': '2007 AD', 'organization_type': ' private Institution ', 'gallery': ['https://media.edusanjal.com/__sized__/gallery/Padmashree_Library-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Food_Preparation_Padmashree-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Culinary_design_Padmashree_International_College-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_6-crop-c0-5__0-5-180x120-70.jpg', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_4-crop-c0-5__0-5-180x120-70.jpg', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_BHM-crop-c0-5__0-5-180x120-70.jpg', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_Activities_4-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_Activities_3-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_Activities_2-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_Activities_1-crop-c0-5__0-5-180x120-70.jpg', 'https://media.edusanjal.com/__sized__/gallery/padmashree_lab-crop-c0-5__0-5-180x120-70.jpg', 'https://media.edusanjal.com/__sized__/gallery/padmashree_computer_lab-crop-c0-5__0-5-180x120-70.jpg', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_Class-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_BHM_Students-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_BHM_Bar-crop-c0-5__0-5-180x120-70.JPG', 'https://media.edusanjal.com/__sized__/gallery/Padmashree_Convocation-crop-c0-5__0-5-180x120-70.JPG'], 'scholarship': {'title': ['Entry Level Scholarships', 'Performance-based Scholarships']}}
